# %% [markdown]
# ## Imports

# %%
import requests
import json
import time
import sys
import os
import dotenv
import pandas as pd

import ipywidgets as widgets

# %% [markdown]
# ## 1) Functions

# %% [markdown]
# ### 1.1) Auth

# %%
# Logging function (minimal logging)
def log_response(response, action):
    print("----------------------")
    print(f"[LOG] {action} Response: Status {response.status_code}")
    print("----------------------")


def parse_json(response_body):
    try:
        return json.loads(response_body)
    except json.JSONDecodeError:
        print("[ERROR] Response is not valid JSON!")
        sys.exit(1)


def fetch_login():
    JWT_ENDPOINT = "https://ant.nvirosense.com/api/v1/login"

    dotenv.load_dotenv()
    NVIRO_USERNAME = os.environ.get("NVIRO_USERNAME")
    NVIRO_PASSWORD = os.environ.get("NVIRO_PASSWORD")
    print(f"[INFO] Authenticating with {JWT_ENDPOINT}...")
    headers = {"Content-Type": "application/json"}
    payload = {
        "user": {
            "login": NVIRO_USERNAME,
            "password": NVIRO_PASSWORD,
        }
    }
    response = requests.post(JWT_ENDPOINT, json=payload, headers=headers)

    return response


def authenticate():

    retries = 0
    MAX_RETRIES = 3
    RETRY_DELAY = 2  # seconds
    while True:
        try:
            response = fetch_login()
            if response.status_code == 200:
                json_response = parse_json(response.text)
                print(json_response)
                jwt_token = json_response.get("token")
                print(jwt_token)
                if not jwt_token:
                    auth_header = response.headers.get("Authorization")
                    if auth_header:
                        parts = auth_header.split(" ")
                        if len(parts) >= 2:
                            jwt_token = parts[-1]
                            print(jwt_token)
                if jwt_token:
                    print("[SUCCESS] Authentication successful! Token received.")
                    return jwt_token
                else:
                    print("[ERROR] Failed to extract token from response!")
                    sys.exit(1)
            else:
                print("[ERROR] Authentication failed! Retrying...")
                raise Exception(f"Auth failed with status {response.status_code}")
        except Exception as e:
            retries += 1
            print(f"[WARN] Attempt {retries}/{MAX_RETRIES} failed: {e}")
            if retries < MAX_RETRIES:
                time.sleep(RETRY_DELAY)
            else:
                print(f"[FATAL] Authentication failed after {MAX_RETRIES} attempts.")
                sys.exit(1)

# %% [markdown]
# ### 1.2) Fetch

# %%
# Function to fetch devices using JWT token
def fetch_devices(jwt_token, is_print=False):
    DEVICES_ENDPOINT = "https://ant.nvirosense.com/api/v1/devices"
    headers = {
        "Authorization": f"Bearer {jwt_token}",
        "Content-Type": "application/json",
    }
    if is_print:
        print(f"[INFO] Fetching devices from {DEVICES_ENDPOINT}...")
    response = requests.get(DEVICES_ENDPOINT, headers=headers)
    if is_print:
        log_response(response, "Fetch Devices")
    if response.status_code == 200:
        devices = parse_json(response.text)
        if is_print:
            print("[SUCCESS] Devices fetched successfully!")
        if is_print:
            print(json.dumps(devices, indent=4))
        return devices
    else:
        print(f"[ERROR] Failed to fetch devices! Status: {response.status_code}")
        return []

def fetch_device_sensors(jwt_token, device, is_print=False):
    DEVICES_ENDPOINT = "https://ant.nvirosense.com/api/v1/devices"
    headers = {
        "Authorization": f"Bearer {jwt_token}",
        "Content-Type": "application/json",
    }
    deviceId = device["devEui"]
    url_endpoint = f"{DEVICES_ENDPOINT}/{deviceId}/sensors"
    if is_print:
        print(f"[INFO] Fetching devices from {url_endpoint}...")
    response = requests.get(url_endpoint, headers=headers)
    if is_print:
        log_response(response, "Fetch Devices")
    if response.status_code == 200:
        devices = parse_json(response.text)
        if is_print:
            print("[SUCCESS] Devices fetched successfully!")
        if is_print:
            print(json.dumps(devices, indent=4))
        return devices["sensors"]
    else:
        print(f"[ERROR] Failed to fetch devices! Status: {response.status_code}")
        return {}

def fetch_sensor_readings(
    jwt_token, device, start_date, end_date, limit=10, page=1, is_print=False
):  
    DEVICES_ENDPOINT = "https://ant.nvirosense.com/api/v1/devices"
    device_id = device["devEui"]
    print(device_id)
    sensor_readings_endpoint = f"{DEVICES_ENDPOINT}/{device_id}/sensor_readings"
    params = {
        "start_date": start_date,
        "end_date": end_date,
        "limit": limit,
        "page": page,
    }
    headers = {
        "Authorization": f"Bearer {jwt_token}",
        "Content-Type": "application/json",
    }
    if is_print:
        print(
            f"[INFO] Fetching sensor readings from {sensor_readings_endpoint} with params {params}..."
        )
    response = requests.get(sensor_readings_endpoint, headers=headers, params=params)
    if is_print:
        log_response(response, "Sensor Readings Fetch")
    if response.status_code == 200:
        readings = parse_json(response.text)
        if is_print:
            print("[SUCCESS] Sensor readings fetched successfully!")
            print(json.dumps(readings, indent=4))
        return readings["sensor_readings"]
    else:
        print(
            f"[ERROR] Failed to fetch sensor readings! Status: {response.status_code}"
        )
        return {}

# %% [markdown]
# ### 1.3) Data Wrangling

# %%
def get_sensors(token, devices: list):
    sensor_list = []
    for device in devices:
        sensors = fetch_device_sensors(token, device)
        for sensor in sensors:
            params = {
                'device_id': device['id'],
                'name': sensor['sensor_name'],
                'unit': sensor['unit'],
            }
            sensor_list.append(params)
    return sensor_list

def add_id(df):
    df.insert(0, 'id', range(1, 1 + len(df)))
    return df

def list_to_df(lst):
    return add_id(pd.DataFrame(lst))


def get_nviro_data(token):
    devices = fetch_devices(token, is_print=False)
    device_list = []
    group_list = []
    for device in devices:
        group_params = {
            'name': device['device_group'],
            'description': device['device_group'],
            'department': device['department'],
        }
        device_params = {
            'name': device['device_name'],
            'devEui': device['devEui'],
            'group': device['device_group'],
        }
        
        device_list.append(device_params)
        if group_params not in group_list:
            group_list.append(group_params)
    df_devices = list_to_df(device_list)
    df_groups = list_to_df(group_list)
    sensor_list = get_sensors(token, df_devices.to_dict('records'))
    df_sensors = list_to_df(sensor_list)

    data = [
        {
            'name': 'Devices',
            'data': df_devices,
        },
        {
            'name': 'Groups',
            'data': df_groups,
        },
        {
            'name': 'Sensors',
            'data': df_sensors,
        }
    ]
    
    return data

# %% [markdown]
# ## 2) Data

# %%
token = authenticate()
# Out:
# [INFO] Authenticating with https://ant.nvirosense.com/api/v1/login...
# {'user': {'id': 'ed850de8-c7ab-45a8-af6b-133b4a1b48e1', 'username': 'WSpamer', 'email': 'wian.spamer@aquanet.co'}}
# None
# eyJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJiMTEwZDVmYy1lNzkyLTQ5YjUtOTlmOS1iNDc3OTU1YjQ2NmEiLCJzdWIiOiJlZDg1MGRlOC1jN2FiLTQ1YTgtYWY2Yi0xMzNiNGExYjQ4ZTEiLCJzY3AiOiJ1c2VyIiwiYXVkIjpudWxsLCJpYXQiOjE3NDY1MzAwMDIsImV4cCI6MTc0NjUzMzYwMn0.opawlNqWiFhrALL_VDEFiaI9Mhlmtg74lB_krSZyhjw
# [SUCCESS] Authentication successful! Token received.

# %%
data = get_nviro_data(token)

# %%
for item in data:
    name = item['name']
    df = item['data']
    print(f"Data for {name}:")
    print(df)
    print("\n")
# Out:
# Data for Devices:
#    id                        name            devEui         group
# 0   1              Replacement IO  a840417f51857c51  Willow Creek
# 1   2      Aquanet I/O Controller  a8404169d1857c61  Willow Creek
# 2   3  Willow Creek IO Controller  a84041c8205b930f  Willow Creek
# 3   4           AquaNet Temp & RH  2cf7f1c0645000ef  Willow Creek
# 4   5            GOEDHALS Weather  2cf7f1c0633000c6      Goedhals
# 5   6        Willow Creek Weather  2cf7f1c06330007c  Willow Creek
# 6   7            ANT Light Sensor  2cf7f1c043900245  Willow Creek
# 7   8                AquaNet Wind  2cf7f1c063300050  Willow Creek
# 8   9        Aquanet Light Sensor  2cf7f1c04390029c  Willow Creek
#
#
# Data for Groups:
#    id          name   description    department
# 0   1  Willow Creek  Willow Creek  Willow Creek
# 1   2      Goedhals      Goedhals    Riversdale
#
#
# Data for Sensors:
#     id  device_id               name unit
# 0    1          1               ACI1    A
# 1    2          1               AVI2    v
# 2    3          1                DO2
# 3    4          1               ACI2    A
# 4    5          1                DI2
# ..  ..        ...                ...  ...
# 59  60          6  CLOUD BASE HEIGHT    m
# 60  61          7              LIGHT  Lux
# 61  62          8         WIND SPEED  m/s
# 62  63          8     WIND DIRECTION    °
# 63  64          9              LIGHT  Lux
#
# [64 rows x 4 columns]

# %% [markdown]
# ### 2.1) Devices

# %%
devices = fetch_devices(token, is_print=False)
# df_devices = pd.DataFrame(devices)
# df_devices.insert(0, 'id', range(1, 1 + len(df_devices)))

# %%
device_list = []
group_list = []
for device in devices:
    group_params = {
        'name': device['device_group'],
        'description': device['device_group'],
        'department': device['department'],
    }
    device_params = {
        'name': device['device_name'],
        'devEui': device['devEui'],
        'group': device['device_group'],
    }
    
    device_list.append(device_params)
    if group_params not in group_list:
        group_list.append(group_params)

# %%
df_devices = add_id(pd.DataFrame(device_list))
df_groups = add_id(pd.DataFrame(group_list))

# %%
# Map group names to IDs
df_devices['group_name'] = df_devices['group']
df_devices['group'] = df_devices['group'].map(df_groups.set_index('name')['id'])

# %% [markdown]
# ### 2.2) Sensors

# %%
devices = df_devices.to_dict('records')

sensor_list = get_sensors(token, devices)

# %%
df_sensors = add_id(pd.DataFrame(sensor_list))

# %% [markdown]
# ### 2.3) Readings

# %%
SAMPLE_START_DATE = "2025-03-01T00:00:00"  # Start date in ISO8601 format
SAMPLE_END_DATE = "2025-03-24T23:59:59"
limit=10 
page=2
device = devices[2]
token = authenticate()
readings = fetch_sensor_readings(token, device, SAMPLE_START_DATE, SAMPLE_END_DATE, limit=limit, page=page)

# %% [markdown]
# #### Nviro through django

# %%
def post_request(data, url):
    x = requests.post(url, json = data)
    print(x.status_code)

def fetch_request(url, data = []):
    print(f"[INFO] Fetching devices from {url}...")
    response = requests.get(url, json = data)
    if response.status_code == 200:
        devices = json.loads(response.text)
        print("[SUCCESS] Devices fetched successfully!")
        return devices
    else:
        print(f"[ERROR] Failed to fetch devices! Status: {response.status_code}")
        return []

# %%
baseUrl = 'http://127.0.0.1:8000'
sensor_reading_url = f"{baseUrl}/nvirosense/reading/"

data = {
    "device_id": device['id'],
    "start_date": SAMPLE_START_DATE,
    "end_date": SAMPLE_END_DATE,
    "limit": limit,
    "page": page,
    
}
post_request(data, sensor_reading_url)
# Out:
# 201

# %%
data = fetch_request( url = sensor_reading_url, data = data)
# Out:
# [INFO] Fetching devices from http://127.0.0.1:8000/nvirosense/reading/...
# [SUCCESS] Devices fetched successfully!

# %%
reading_list = []
for reading in data:
    datetime = reading['received_at']
    sensors = reading['sensor_data']
    print(sensors)
    # for sensor in sensors:

    #     device_sensor = [device_sensor for device_sensor in device_sensors if device_sensor['name'] == sensor['sensor_name']][0]
    #     value = sensor['value']
    #     params = device_sensor.copy()
    #     params['datetime'] = datetime
    #     params['value'] = value
    #     reading_list.append(params)
# Out:
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1409', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '444.99', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.53', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.21', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.51', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.75', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '10700.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97370.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '88.81', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.18', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.78', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.18', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '23.6', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '0.0', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1407', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '455.71', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.46', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.20', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.57', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.31', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '9545.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97360.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '79.22', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.2', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.74', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.20', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '325.9', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '1.2', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1405', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '463.27', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.48', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.26', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.70', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.0', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '17275.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97370.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '143.38', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.28', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.77', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.28', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '326.1', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '1.1', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1400', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '442.06', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.79', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.43', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.87', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.87', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '17035.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97380.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '141.39', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.42', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '22.03', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.42', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '326.5', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '1.7', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1406', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '462.54', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.49', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.26', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.70', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.03', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '28350.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97380.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '235.31', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.28', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.78', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.28', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '51.3', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '0.8', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1409', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '426.46', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.71', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.28', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.51', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '82.51', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '24930.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97380.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '206.92', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.21', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.91', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.21', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '318.2', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '0.8', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1415', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '430.11', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.55', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.15', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.32', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '82.36', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '18815.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97390.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '156.16', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.08', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.76', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.08', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '323.6', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '1.1', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1411', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '450.84', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.44', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.16', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.47', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.51', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '23730.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97380.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '196.96', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.14', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.71', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.14', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '299.9', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '1.3', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1409', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '461.32', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.44', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.21', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '24.61', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.08', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '19105.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97390.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '158.57', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.22', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '21.73', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.22', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '323.8', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '0.9', 'unit': 'm/s'}]
# [{'sensor_name': 'ABSOLUTE HUMIDITY', 'value': '0.18', 'unit': 'g/m3'}, {'sensor_name': 'ACCUMULATIVE RAINFALL', 'value': '22.8', 'unit': 'mm'}, {'sensor_name': 'AIR DENSITY', 'value': '1.1399', 'unit': 'kg/m3'}, {'sensor_name': 'CLOUD BASE HEIGHT', 'value': '458.64', 'unit': 'm'}, {'sensor_name': 'DEW POINT', 'value': '20.80', 'unit': '°C'}, {'sensor_name': 'DISCOMFORT INDEX', 'value': '23.52', 'unit': '°C'}, {'sensor_name': 'HEAT INDEX', 'value': '25.13', 'unit': '°C'}, {'sensor_name': 'HUMIDITY', 'value': '81.19', 'unit': '%RH'}, {'sensor_name': 'LIGHT', 'value': '14600.0', 'unit': 'Lux'}, {'sensor_name': 'PRESSURE', 'value': '97410.0', 'unit': 'Pa'}, {'sensor_name': 'SOLAR RADIATION', 'value': '121.18', 'unit': 'W/m2'}, {'sensor_name': 'TEMPERATURE', 'value': '24.56', 'unit': '°C'}, {'sensor_name': 'WET BULB TEMPERATURE', 'value': '22.07', 'unit': '°C'}, {'sensor_name': 'WIND CHILL', 'value': '24.56', 'unit': '°C'}, {'sensor_name': 'WIND DIRECTION', 'value': '242.7', 'unit': '°'}, {'sensor_name': 'WIND SPEED', 'value': '1.4', 'unit': 'm/s'}]

# %%
print(p)
# Out:
# None

# %%
reading_list = []
for reading in readings:
        datetime = reading['received_at']
        sensors = reading['sensor_data']
        # sensors2 = df_sensors.to_dict('records')
        # print(sensors2)
        # print(sensors)
        # print(sensor_list)
        for sensor in sensors:
                device_sensor = [device_sensor for device_sensor in df_sensors.to_dict('records') if device_sensor['name'] == sensor['sensor_name']][0]
                value = sensor['value']
                params = {
                        'sensor_id': device_sensor['id'],
                        'sensor_name': sensor['sensor_name'],
                        'datetime': datetime,
                        'value': value,
                }
                reading_list.append(params)
df_readings = add_id(pd.DataFrame(reading_list))

# %% [markdown]
# ## 3) Export

# %%
with pd.ExcelWriter('nviro_data.xlsx') as writer:  
    df_groups.to_excel(writer, sheet_name='Groups', index=False)
    df_devices.to_excel(writer, sheet_name='Devices', index=False)
    df_sensors.to_excel(writer, sheet_name='Sensors', index=False)

# %%
df_groups.to_csv('data/groups.csv', index=False)
df_devices.to_csv('data/devices.csv', index=False)
df_sensors.to_csv('data/sensors.csv', index=False)

# %% [markdown]
# ## 4) UI

# %% [markdown]
# ### 4.1) Functions

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
def selectize_list(lst, label, variable):
    select_options = []
    for r in lst:
        select_options.append((r[label], r[variable]))
    
    return select_options

def get_selected_option(w_input, lst: list, variable: str):
    selected_device = [r for r in lst if r[variable] == w_input.value][0]
    
    return selected_device

def device_dropdown(device_list):
    select_options = selectize_list(device_list, 'name', 'devEui')
    device_input = widgets.Dropdown(
        options=select_options,
        value=select_options[0][1],
        description='Device:',
        disabled=False,
    )
    
    return device_input

# %%
from nviro_data.django import fetch_request
device_list = fetch_request('device')
# Out:
# [INFO] Fetching devices from http://127.0.0.1:8000/api/device...
# [SUCCESS] Devices fetched successfully!

# %% [markdown]
# ### 4.2) Inputs

# %%
device_input = device_dropdown(device_list)
start_date_input = widgets.DatePicker(
    description='Start Date',
    disabled=False
)
end_date_input = widgets.DatePicker(
    description='End Date',
    disabled=False
)
limit_input = widgets.IntSlider(
    value=10,
    min=10,
    max=10000,
    step=10,
    description='Limit:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
page_input = widgets.IntSlider(
    value=1,
    min=1,
    max=10,
    step=1,
    description='Page:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)

# %%
display(device_input)
display(start_date_input)
display(end_date_input)
display(limit_input)
display(page_input)
# Out:
# Dropdown(description='Device:', options=(('GOEDHALS Weather', '2cf7f1c0633000c6'), ('AquaNet Temp & RH', '2cf7…
# DatePicker(value=None, description='Start Date', step=1)
# DatePicker(value=None, description='End Date', step=1)
# IntSlider(value=10, continuous_update=False, description='Limit:', max=10000, min=10, step=10)
# IntSlider(value=1, continuous_update=False, description='Page:', max=10, min=1)

# %%
selected_device = get_selected_option(device_input, device_list, 'devEui')
print(selected_device)
# Out:
# {'id': 1, 'name': 'GOEDHALS Weather', 'devEui': '2cf7f1c0633000c6', 'group': 1}

# %%
start_date = start_date_input.value
end_date = end_date_input.value
limit = limit_input.value
page = page_input.value

# %% [markdown]
# ## 5) Post to database

# %%
from nviro_data.django import fetch_data
db_sensor = fetch_data(f'sensor/?device__id={selected_device['id']}')

def get_readings(readings, selected_device):
    db_sensor = fetch_data(f'sensor/?device__id={selected_device['id']}')
    reading_list = []
    for reading in readings:
        datetime = reading['received_at']
        sensors = reading['sensor_data']
        for sensor in sensors:
            sensor_id = [db_sensor['id'] for db_sensor in db_sensor.to_dict('records') if db_sensor['name'] == sensor['sensor_name']][0]
            params = {
                'datetime': datetime,
                'sensor_id': sensor_id,
                'value': sensor['value'],
            }
            print(params)
            reading_list.append(params)
    df_readings = pd.DataFrame(reading_list)
    return df_readings
# Out:
# [INFO] Fetching devices from http://127.0.0.1:8000/api/sensor/?device__id=1...
# [SUCCESS] Devices fetched successfully!

# %%
token = authenticate()
readings = fetch_sensor_readings(token, selected_device, start_date, end_date, limit=limit, page=page, is_print=True)
# Out:
# [INFO] Authenticating with https://ant.nvirosense.com/api/v1/login...
# {'user': {'id': 'ed850de8-c7ab-45a8-af6b-133b4a1b48e1', 'username': 'WSpamer', 'email': 'wian.spamer@aquanet.co'}}
# None
# eyJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJiMTEwZDVmYy1lNzkyLTQ5YjUtOTlmOS1iNDc3OTU1YjQ2NmEiLCJzdWIiOiJlZDg1MGRlOC1jN2FiLTQ1YTgtYWY2Yi0xMzNiNGExYjQ4ZTEiLCJzY3AiOiJ1c2VyIiwiYXVkIjpudWxsLCJpYXQiOjE3NDU0MjAzMzIsImV4cCI6MTc0NTQyMzkzMn0.rd5w2KQUicG0B69XZuhxCfGpGO8ivXRpU03VqAIpEyY
# [SUCCESS] Authentication successful! Token received.
# 2cf7f1c0633000c6
# [INFO] Fetching sensor readings from https://ant.nvirosense.com/api/v1/devices/2cf7f1c0633000c6/sensor_readings with params {'start_date': datetime.date(2025, 4, 18), 'end_date': datetime.date(2025, 4, 22), 'limit': 90, 'page': 1}...
# ----------------------
# [LOG] Sensor Readings Fetch Response: Status 200
# ----------------------
# [SUCCESS] Sensor readings fetched successfully!
# {
#     "device": {
#         "devEui": "2CF7F1C0633000C6",
#         "device_name": "GOEDHALS Weather"
#     },
#     "sensor_readings": [
#         {
#             "received_at": "2025-04-21 23:55",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "28.77",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.79",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.05",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.61",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.82",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96910.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.03",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.86",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.03",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "137.5",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.0",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:50",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "29.99",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.76",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.03",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.68",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.77",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96920.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.01",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.83",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.01",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "141.6",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.6",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:45",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "29.02",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.82",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.08",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.57",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.81",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96920.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.06",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.89",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.06",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "154.7",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.8",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:40",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "29.26",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.79",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.05",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.62",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.8",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96920.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.03",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.85",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.03",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "143.2",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.2",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:35",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "29.50",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.8",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.06",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.62",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.79",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96930.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.04",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.86",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.04",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "142.1",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "1.5",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:30",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "29.02",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.8",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.06",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.6",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.81",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.04",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.87",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.04",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "137.3",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "1.5",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:25",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "29.26",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.78",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.04",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.64",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.8",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.02",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.84",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.02",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "140.3",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.4",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:20",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "30.48",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.75",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.02",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.71",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.75",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96950.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.0",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.82",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.0",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "136.3",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "1.6",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:15",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "30.97",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.75",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.02",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.72",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.73",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.0",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.82",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.0",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "138.0",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.1",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:10",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "30.72",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.75",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.02",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.72",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.74",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.0",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.82",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.0",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "145.4",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.1",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:05",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.11",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "30.23",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.76",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "12.03",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.69",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.76",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "12.01",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.83",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "12.01",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "135.0",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.8",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 23:00",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "30.48",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.7",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.97",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.79",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.75",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.95",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.77",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.95",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "123.5",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.0",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:55",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "31.45",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.64",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.92",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.9",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.71",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.9",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.71",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.9",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "131.9",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.3",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:50",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "31.70",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.62",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.90",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.94",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.7",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96930.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.88",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.69",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.88",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "121.2",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.7",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:45",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "33.16",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.59",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.88",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.02",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.64",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96930.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.86",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.67",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.86",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "136.2",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.5",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:40",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "33.65",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.58",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.88",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.04",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.62",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96930.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.86",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.66",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.86",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "132.5",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.2",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:35",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "33.65",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.6",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.90",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.0",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.62",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.88",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.68",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.88",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "119.5",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "2.3",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:30",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "32.43",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.6",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.89",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "17.98",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.67",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.87",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.68",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.87",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "121.2",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.0",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:25",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "34.14",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.57",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.87",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.07",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.6",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.85",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.65",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.85",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "132.4",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.3",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:20",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "33.65",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.53",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.83",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.12",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.62",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96930.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.81",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.61",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.81",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "126.4",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "6.1",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:15",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "34.14",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.49",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.79",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.2",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.6",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96940.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.77",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.57",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.77",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "126.7",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.0",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:10",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "35.60",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.45",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.76",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.3",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.54",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96950.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.74",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.54",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.74",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "130.2",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "3.3",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 22:05",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "36.57",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.42",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.74",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.36",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.5",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96930.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.72",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.51",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.72",
# ...
#                     "value": "11.36",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "19.18",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.35",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96860.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.33",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.10",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.33",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "143.2",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "5.7",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 17:00",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "39.26",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "10.97",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.32",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "19.22",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.39",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96850.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.29",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.07",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.29",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "138.5",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "5.8",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 16:55",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "40.23",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "10.97",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.33",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "19.23",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.35",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96850.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.3",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.07",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.3",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "141.5",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "6.7",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 16:50",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "40.23",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.03",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.39",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "19.12",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.35",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96840.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.36",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.13",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.36",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "149.3",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "7.4",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 16:45",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "43.16",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.16",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.54",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.93",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.23",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96830.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.51",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.27",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.51",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "142.7",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "8.3",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 16:40",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "35.36",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.37",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.68",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.43",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.55",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96820.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.66",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.46",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.66",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "146.8",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "7.5",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 16:35",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "35.60",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.26",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.57",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.63",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.54",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96830.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.55",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.34",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.55",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "141.3",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "5.1",
#                     "unit": "m/s"
#                 }
#             ]
#         },
#         {
#             "received_at": "2025-04-21 16:30",
#             "sensor_data": [
#                 {
#                     "sensor_name": "ABSOLUTE HUMIDITY",
#                     "value": "0.10",
#                     "unit": "g/m3"
#                 },
#                 {
#                     "sensor_name": "CLOUD BASE HEIGHT",
#                     "value": "37.31",
#                     "unit": "m"
#                 },
#                 {
#                     "sensor_name": "DEW POINT",
#                     "value": "11.24",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "DISCOMFORT INDEX",
#                     "value": "11.57",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HEAT INDEX",
#                     "value": "18.69",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "HUMIDITY",
#                     "value": "98.47",
#                     "unit": "%RH"
#                 },
#                 {
#                     "sensor_name": "PRESSURE",
#                     "value": "96820.0",
#                     "unit": "Pa"
#                 },
#                 {
#                     "sensor_name": "TEMPERATURE",
#                     "value": "11.55",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WET BULB TEMPERATURE",
#                     "value": "11.34",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND CHILL",
#                     "value": "11.55",
#                     "unit": "\u00b0C"
#                 },
#                 {
#                     "sensor_name": "WIND DIRECTION",
#                     "value": "140.7",
#                     "unit": "\u00b0"
#                 },
#                 {
#                     "sensor_name": "WIND SPEED",
#                     "value": "6.3",
#                     "unit": "m/s"
#                 }
#             ]
#         }
#     ],
#     "sensor_value_count": 1152,
#     "pagination": {
#         "page": 1,
#         "items": 90,
#         "total_pages": 13,
#         "total_count": 1152
#     }
# }

# %%
df_readings = get_readings(readings, selected_device)
# Out:
# [INFO] Fetching devices from http://127.0.0.1:8000/api/sensor/?device__id=1...
# [SUCCESS] Devices fetched successfully!
# {'datetime': '2025-04-21 23:55', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 12, 'value': '28.77'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 5, 'value': '11.79'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 8, 'value': '12.05'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 6, 'value': '17.61'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 2, 'value': '98.82'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 11, 'value': '96910.0'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 1, 'value': '12.03'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 10, 'value': '11.86'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 7, 'value': '12.03'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 4, 'value': '137.5'}
# {'datetime': '2025-04-21 23:55', 'sensor_id': 3, 'value': '3.0'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 12, 'value': '29.99'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 5, 'value': '11.76'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 8, 'value': '12.03'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 6, 'value': '17.68'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 2, 'value': '98.77'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 11, 'value': '96920.0'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 1, 'value': '12.01'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 10, 'value': '11.83'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 7, 'value': '12.01'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 4, 'value': '141.6'}
# {'datetime': '2025-04-21 23:50', 'sensor_id': 3, 'value': '3.6'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 12, 'value': '29.02'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 5, 'value': '11.82'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 8, 'value': '12.08'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 6, 'value': '17.57'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 2, 'value': '98.81'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 11, 'value': '96920.0'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 1, 'value': '12.06'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 10, 'value': '11.89'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 7, 'value': '12.06'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 4, 'value': '154.7'}
# {'datetime': '2025-04-21 23:45', 'sensor_id': 3, 'value': '2.8'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 12, 'value': '29.26'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 5, 'value': '11.79'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 8, 'value': '12.05'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 6, 'value': '17.62'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 2, 'value': '98.8'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 11, 'value': '96920.0'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 1, 'value': '12.03'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 10, 'value': '11.85'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 7, 'value': '12.03'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 4, 'value': '143.2'}
# {'datetime': '2025-04-21 23:40', 'sensor_id': 3, 'value': '2.2'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 12, 'value': '29.50'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 5, 'value': '11.8'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 8, 'value': '12.06'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 6, 'value': '17.62'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 2, 'value': '98.79'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 1, 'value': '12.04'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 10, 'value': '11.86'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 7, 'value': '12.04'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 4, 'value': '142.1'}
# {'datetime': '2025-04-21 23:35', 'sensor_id': 3, 'value': '1.5'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 12, 'value': '29.02'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 5, 'value': '11.8'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 8, 'value': '12.06'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 6, 'value': '17.6'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 2, 'value': '98.81'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 1, 'value': '12.04'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 10, 'value': '11.87'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 7, 'value': '12.04'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 4, 'value': '137.3'}
# {'datetime': '2025-04-21 23:30', 'sensor_id': 3, 'value': '1.5'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 12, 'value': '29.26'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 5, 'value': '11.78'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 8, 'value': '12.04'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 6, 'value': '17.64'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 2, 'value': '98.8'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 1, 'value': '12.02'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 10, 'value': '11.84'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 7, 'value': '12.02'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 4, 'value': '140.3'}
# {'datetime': '2025-04-21 23:25', 'sensor_id': 3, 'value': '2.4'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 12, 'value': '30.48'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 5, 'value': '11.75'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 8, 'value': '12.02'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 6, 'value': '17.71'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 2, 'value': '98.75'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 11, 'value': '96950.0'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 1, 'value': '12.0'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 10, 'value': '11.82'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 7, 'value': '12.0'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 4, 'value': '136.3'}
# {'datetime': '2025-04-21 23:20', 'sensor_id': 3, 'value': '1.6'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 12, 'value': '30.97'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 5, 'value': '11.75'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 8, 'value': '12.02'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 6, 'value': '17.72'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 2, 'value': '98.73'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 1, 'value': '12.0'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 10, 'value': '11.82'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 7, 'value': '12.0'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 4, 'value': '138.0'}
# {'datetime': '2025-04-21 23:15', 'sensor_id': 3, 'value': '2.1'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 12, 'value': '30.72'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 5, 'value': '11.75'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 8, 'value': '12.02'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 6, 'value': '17.72'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 2, 'value': '98.74'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 1, 'value': '12.0'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 10, 'value': '11.82'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 7, 'value': '12.0'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 4, 'value': '145.4'}
# {'datetime': '2025-04-21 23:10', 'sensor_id': 3, 'value': '2.1'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 9, 'value': '0.11'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 12, 'value': '30.23'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 5, 'value': '11.76'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 8, 'value': '12.03'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 6, 'value': '17.69'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 2, 'value': '98.76'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 1, 'value': '12.01'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 10, 'value': '11.83'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 7, 'value': '12.01'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 4, 'value': '135.0'}
# {'datetime': '2025-04-21 23:05', 'sensor_id': 3, 'value': '2.8'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 12, 'value': '30.48'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 5, 'value': '11.7'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 8, 'value': '11.97'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 6, 'value': '17.79'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 2, 'value': '98.75'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 1, 'value': '11.95'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 10, 'value': '11.77'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 7, 'value': '11.95'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 4, 'value': '123.5'}
# {'datetime': '2025-04-21 23:00', 'sensor_id': 3, 'value': '3.0'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 12, 'value': '31.45'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 5, 'value': '11.64'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 8, 'value': '11.92'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 6, 'value': '17.9'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 2, 'value': '98.71'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 1, 'value': '11.9'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 10, 'value': '11.71'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 7, 'value': '11.9'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 4, 'value': '131.9'}
# {'datetime': '2025-04-21 22:55', 'sensor_id': 3, 'value': '2.3'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 12, 'value': '31.70'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 5, 'value': '11.62'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 8, 'value': '11.90'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 6, 'value': '17.94'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 2, 'value': '98.7'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 1, 'value': '11.88'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 10, 'value': '11.69'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 7, 'value': '11.88'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 4, 'value': '121.2'}
# {'datetime': '2025-04-21 22:50', 'sensor_id': 3, 'value': '2.7'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 12, 'value': '33.16'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 5, 'value': '11.59'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 8, 'value': '11.88'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 6, 'value': '18.02'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 2, 'value': '98.64'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 1, 'value': '11.86'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 10, 'value': '11.67'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 7, 'value': '11.86'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 4, 'value': '136.2'}
# {'datetime': '2025-04-21 22:45', 'sensor_id': 3, 'value': '3.5'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 12, 'value': '33.65'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 5, 'value': '11.58'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 8, 'value': '11.88'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 6, 'value': '18.04'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 2, 'value': '98.62'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 1, 'value': '11.86'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 10, 'value': '11.66'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 7, 'value': '11.86'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 4, 'value': '132.5'}
# {'datetime': '2025-04-21 22:40', 'sensor_id': 3, 'value': '3.2'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 12, 'value': '33.65'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 5, 'value': '11.6'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 8, 'value': '11.90'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 6, 'value': '18.0'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 2, 'value': '98.62'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 1, 'value': '11.88'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 10, 'value': '11.68'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 7, 'value': '11.88'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 4, 'value': '119.5'}
# {'datetime': '2025-04-21 22:35', 'sensor_id': 3, 'value': '2.3'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 12, 'value': '32.43'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 5, 'value': '11.6'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 8, 'value': '11.89'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 6, 'value': '17.98'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 2, 'value': '98.67'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 1, 'value': '11.87'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 10, 'value': '11.68'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 7, 'value': '11.87'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 4, 'value': '121.2'}
# {'datetime': '2025-04-21 22:30', 'sensor_id': 3, 'value': '3.0'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 12, 'value': '34.14'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 5, 'value': '11.57'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 8, 'value': '11.87'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 6, 'value': '18.07'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 2, 'value': '98.6'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 1, 'value': '11.85'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 10, 'value': '11.65'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 7, 'value': '11.85'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 4, 'value': '132.4'}
# {'datetime': '2025-04-21 22:25', 'sensor_id': 3, 'value': '3.3'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 12, 'value': '33.65'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 5, 'value': '11.53'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 8, 'value': '11.83'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 6, 'value': '18.12'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 2, 'value': '98.62'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 1, 'value': '11.81'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 10, 'value': '11.61'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 7, 'value': '11.81'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 4, 'value': '126.4'}
# {'datetime': '2025-04-21 22:20', 'sensor_id': 3, 'value': '6.1'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 12, 'value': '34.14'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 5, 'value': '11.49'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 8, 'value': '11.79'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 6, 'value': '18.2'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 2, 'value': '98.6'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 1, 'value': '11.77'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 10, 'value': '11.57'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 7, 'value': '11.77'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 4, 'value': '126.7'}
# {'datetime': '2025-04-21 22:15', 'sensor_id': 3, 'value': '3.0'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 12, 'value': '35.60'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 5, 'value': '11.45'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 8, 'value': '11.76'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 6, 'value': '18.3'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 2, 'value': '98.54'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 11, 'value': '96950.0'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 1, 'value': '11.74'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 10, 'value': '11.54'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 7, 'value': '11.74'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 4, 'value': '130.2'}
# {'datetime': '2025-04-21 22:10', 'sensor_id': 3, 'value': '3.3'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 12, 'value': '36.57'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 5, 'value': '11.42'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 8, 'value': '11.74'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 6, 'value': '18.36'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 2, 'value': '98.5'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 1, 'value': '11.72'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 10, 'value': '11.51'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 7, 'value': '11.72'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 4, 'value': '130.7'}
# {'datetime': '2025-04-21 22:05', 'sensor_id': 3, 'value': '3.7'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 12, 'value': '36.57'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 5, 'value': '11.45'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 8, 'value': '11.77'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 6, 'value': '18.31'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 2, 'value': '98.5'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 11, 'value': '96950.0'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 1, 'value': '11.75'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 10, 'value': '11.54'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 7, 'value': '11.75'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 4, 'value': '126.8'}
# {'datetime': '2025-04-21 22:00', 'sensor_id': 3, 'value': '3.0'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 12, 'value': '35.60'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 5, 'value': '11.37'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 8, 'value': '11.68'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 6, 'value': '18.44'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 2, 'value': '98.54'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 11, 'value': '96950.0'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 1, 'value': '11.66'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 10, 'value': '11.46'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 7, 'value': '11.66'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 4, 'value': '108.7'}
# {'datetime': '2025-04-21 21:55', 'sensor_id': 3, 'value': '2.3'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 12, 'value': '37.79'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 5, 'value': '11.31'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 8, 'value': '11.64'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 6, 'value': '18.58'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 2, 'value': '98.45'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 1, 'value': '11.62'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 10, 'value': '11.41'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 7, 'value': '11.62'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 4, 'value': '97.6'}
# {'datetime': '2025-04-21 21:50', 'sensor_id': 3, 'value': '2.6'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 12, 'value': '38.04'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 5, 'value': '11.24'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 8, 'value': '11.58'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 6, 'value': '18.71'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 2, 'value': '98.44'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 1, 'value': '11.55'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 10, 'value': '11.33'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 7, 'value': '11.55'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 4, 'value': '101.4'}
# {'datetime': '2025-04-21 21:45', 'sensor_id': 3, 'value': '3.0'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 12, 'value': '39.01'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 5, 'value': '11.2'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 8, 'value': '11.55'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 6, 'value': '18.79'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 2, 'value': '98.4'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 1, 'value': '11.52'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 10, 'value': '11.30'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 7, 'value': '11.52'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 4, 'value': '97.3'}
# {'datetime': '2025-04-21 21:40', 'sensor_id': 3, 'value': '2.9'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 12, 'value': '39.01'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 5, 'value': '11.17'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 8, 'value': '11.52'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 6, 'value': '18.85'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 2, 'value': '98.4'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 1, 'value': '11.49'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 10, 'value': '11.27'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 7, 'value': '11.49'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 4, 'value': '106.9'}
# {'datetime': '2025-04-21 21:35', 'sensor_id': 3, 'value': '3.0'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 12, 'value': '39.99'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 5, 'value': '11.16'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 8, 'value': '11.52'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 6, 'value': '18.87'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 2, 'value': '98.36'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 1, 'value': '11.49'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 10, 'value': '11.27'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 7, 'value': '11.49'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 4, 'value': '111.5'}
# {'datetime': '2025-04-21 21:30', 'sensor_id': 3, 'value': '2.5'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 12, 'value': '41.45'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 5, 'value': '11.22'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 8, 'value': '11.59'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 6, 'value': '18.79'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 2, 'value': '98.3'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 1, 'value': '11.56'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 10, 'value': '11.33'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 7, 'value': '11.56'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 4, 'value': '86.8'}
# {'datetime': '2025-04-21 21:25', 'sensor_id': 3, 'value': '3.1'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 12, 'value': '38.28'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 5, 'value': '11.27'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 8, 'value': '11.61'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 6, 'value': '18.66'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 2, 'value': '98.43'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 1, 'value': '11.58'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 10, 'value': '11.36'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 7, 'value': '11.58'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 4, 'value': '99.6'}
# {'datetime': '2025-04-21 21:20', 'sensor_id': 3, 'value': '2.0'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 12, 'value': '38.28'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 5, 'value': '11.2'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 8, 'value': '11.54'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 6, 'value': '18.79'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 2, 'value': '98.43'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 1, 'value': '11.51'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 10, 'value': '11.29'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 7, 'value': '11.51'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 4, 'value': '118.0'}
# {'datetime': '2025-04-21 21:15', 'sensor_id': 3, 'value': '2.6'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 12, 'value': '39.26'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 5, 'value': '11.19'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 8, 'value': '11.54'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 6, 'value': '18.82'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 2, 'value': '98.39'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 1, 'value': '11.51'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 10, 'value': '11.29'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 7, 'value': '11.51'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 4, 'value': '96.4'}
# {'datetime': '2025-04-21 21:10', 'sensor_id': 3, 'value': '3.8'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 12, 'value': '38.52'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 5, 'value': '11.26'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 8, 'value': '11.61'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 6, 'value': '18.67'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 2, 'value': '98.42'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 1, 'value': '11.58'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 10, 'value': '11.36'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 7, 'value': '11.58'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 4, 'value': '110.8'}
# {'datetime': '2025-04-21 21:05', 'sensor_id': 3, 'value': '4.6'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 12, 'value': '35.84'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 5, 'value': '11.25'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 8, 'value': '11.56'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 6, 'value': '18.66'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 2, 'value': '98.53'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 1, 'value': '11.54'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 10, 'value': '11.33'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 7, 'value': '11.54'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 4, 'value': '104.2'}
# {'datetime': '2025-04-21 21:00', 'sensor_id': 3, 'value': '3.6'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 12, 'value': '35.60'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 5, 'value': '11.21'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 8, 'value': '11.52'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 6, 'value': '18.72'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 2, 'value': '98.54'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 11, 'value': '96950.0'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 1, 'value': '11.5'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 10, 'value': '11.29'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 7, 'value': '11.5'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 4, 'value': '122.3'}
# {'datetime': '2025-04-21 20:55', 'sensor_id': 3, 'value': '3.7'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 12, 'value': '36.09'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 5, 'value': '11.15'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 8, 'value': '11.47'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 6, 'value': '18.83'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 2, 'value': '98.52'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 1, 'value': '11.45'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 10, 'value': '11.24'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 7, 'value': '11.45'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 4, 'value': '117.0'}
# {'datetime': '2025-04-21 20:50', 'sensor_id': 3, 'value': '4.2'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 12, 'value': '34.87'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 5, 'value': '11.16'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 8, 'value': '11.47'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 6, 'value': '18.79'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 2, 'value': '98.57'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 1, 'value': '11.45'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 10, 'value': '11.25'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 7, 'value': '11.45'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 4, 'value': '130.6'}
# {'datetime': '2025-04-21 20:45', 'sensor_id': 3, 'value': '2.9'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 12, 'value': '36.82'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 5, 'value': '11.07'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 8, 'value': '11.40'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 6, 'value': '19.0'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 2, 'value': '98.49'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 11, 'value': '96950.0'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 1, 'value': '11.37'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 10, 'value': '11.16'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 7, 'value': '11.37'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 4, 'value': '126.6'}
# {'datetime': '2025-04-21 20:40', 'sensor_id': 3, 'value': '2.7'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 12, 'value': '36.57'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 5, 'value': '11.03'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 8, 'value': '11.36'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 6, 'value': '19.07'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 2, 'value': '98.5'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 11, 'value': '96950.0'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 1, 'value': '11.33'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 10, 'value': '11.12'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 7, 'value': '11.33'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 4, 'value': '108.5'}
# {'datetime': '2025-04-21 20:35', 'sensor_id': 3, 'value': '4.6'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 12, 'value': '37.31'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 5, 'value': '11.01'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 8, 'value': '11.35'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 6, 'value': '19.11'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 2, 'value': '98.47'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 1, 'value': '11.32'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 10, 'value': '11.11'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 7, 'value': '11.32'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 4, 'value': '96.6'}
# {'datetime': '2025-04-21 20:30', 'sensor_id': 3, 'value': '4.7'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 12, 'value': '37.06'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 5, 'value': '11.05'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 8, 'value': '11.38'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 6, 'value': '19.04'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 2, 'value': '98.48'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 1, 'value': '11.35'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 10, 'value': '11.14'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 7, 'value': '11.35'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 4, 'value': '95.8'}
# {'datetime': '2025-04-21 20:25', 'sensor_id': 3, 'value': '4.6'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 12, 'value': '35.84'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 5, 'value': '11.1'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 8, 'value': '11.42'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 6, 'value': '18.93'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 2, 'value': '98.53'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 1, 'value': '11.39'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 10, 'value': '11.18'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 7, 'value': '11.39'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 4, 'value': '111.7'}
# {'datetime': '2025-04-21 20:20', 'sensor_id': 3, 'value': '4.4'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 12, 'value': '35.11'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 5, 'value': '11.07'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 8, 'value': '11.38'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 6, 'value': '18.97'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 2, 'value': '98.56'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 11, 'value': '96920.0'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 1, 'value': '11.36'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 10, 'value': '11.16'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 7, 'value': '11.36'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 4, 'value': '103.4'}
# {'datetime': '2025-04-21 20:15', 'sensor_id': 3, 'value': '3.2'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 12, 'value': '38.28'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 5, 'value': '11.09'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 8, 'value': '11.43'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 6, 'value': '18.99'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 2, 'value': '98.43'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 1, 'value': '11.4'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 10, 'value': '11.18'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 7, 'value': '11.4'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 4, 'value': '105.9'}
# {'datetime': '2025-04-21 20:10', 'sensor_id': 3, 'value': '4.7'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 12, 'value': '37.06'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 5, 'value': '11.13'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 8, 'value': '11.46'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 6, 'value': '18.9'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 2, 'value': '98.48'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 11, 'value': '96940.0'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 1, 'value': '11.43'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 10, 'value': '11.22'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 7, 'value': '11.43'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 4, 'value': '98.2'}
# {'datetime': '2025-04-21 20:05', 'sensor_id': 3, 'value': '5.2'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 12, 'value': '35.60'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 5, 'value': '11.1'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 8, 'value': '11.41'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 6, 'value': '18.93'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 2, 'value': '98.54'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 1, 'value': '11.39'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 10, 'value': '11.18'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 7, 'value': '11.39'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 4, 'value': '118.3'}
# {'datetime': '2025-04-21 20:00', 'sensor_id': 3, 'value': '2.2'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 12, 'value': '38.04'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 5, 'value': '11.04'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 8, 'value': '11.38'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 6, 'value': '19.07'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 2, 'value': '98.44'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 11, 'value': '96930.0'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 1, 'value': '11.35'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 10, 'value': '11.13'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 7, 'value': '11.35'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 4, 'value': '125.7'}
# {'datetime': '2025-04-21 19:55', 'sensor_id': 3, 'value': '4.0'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 12, 'value': '38.28'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 5, 'value': '11.02'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 8, 'value': '11.36'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 6, 'value': '19.12'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 2, 'value': '98.43'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 11, 'value': '96920.0'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 1, 'value': '11.33'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 10, 'value': '11.11'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 7, 'value': '11.33'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 4, 'value': '132.6'}
# {'datetime': '2025-04-21 19:50', 'sensor_id': 3, 'value': '3.7'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 12, 'value': '38.77'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 5, 'value': '10.99'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 8, 'value': '11.34'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 6, 'value': '19.17'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 2, 'value': '98.41'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 11, 'value': '96920.0'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 1, 'value': '11.31'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 10, 'value': '11.09'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 7, 'value': '11.31'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 4, 'value': '131.2'}
# {'datetime': '2025-04-21 19:45', 'sensor_id': 3, 'value': '4.1'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 12, 'value': '38.28'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 5, 'value': '10.94'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 8, 'value': '11.28'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 6, 'value': '19.27'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 2, 'value': '98.43'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 11, 'value': '96910.0'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 1, 'value': '11.25'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 10, 'value': '11.03'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 7, 'value': '11.25'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 4, 'value': '127.1'}
# {'datetime': '2025-04-21 19:40', 'sensor_id': 3, 'value': '5.6'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 12, 'value': '38.28'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 5, 'value': '10.94'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 8, 'value': '11.28'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 6, 'value': '19.27'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 2, 'value': '98.43'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 11, 'value': '96910.0'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 1, 'value': '11.25'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 10, 'value': '11.03'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 7, 'value': '11.25'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 4, 'value': '134.5'}
# {'datetime': '2025-04-21 19:35', 'sensor_id': 3, 'value': '3.7'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 12, 'value': '37.55'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 5, 'value': '10.9'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 8, 'value': '11.24'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 6, 'value': '19.32'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 2, 'value': '98.46'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 11, 'value': '96900.0'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 1, 'value': '11.21'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 10, 'value': '11.00'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 7, 'value': '11.21'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 4, 'value': '133.6'}
# {'datetime': '2025-04-21 19:30', 'sensor_id': 3, 'value': '4.0'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 12, 'value': '36.57'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 5, 'value': '10.93'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 8, 'value': '11.26'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 6, 'value': '19.26'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 2, 'value': '98.5'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 11, 'value': '96910.0'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 1, 'value': '11.23'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 10, 'value': '11.02'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 7, 'value': '11.23'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 4, 'value': '129.6'}
# {'datetime': '2025-04-21 19:25', 'sensor_id': 3, 'value': '4.5'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 12, 'value': '35.84'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 5, 'value': '10.96'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 8, 'value': '11.28'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 6, 'value': '19.2'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 2, 'value': '98.53'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 11, 'value': '96910.0'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 1, 'value': '11.25'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 10, 'value': '11.04'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 7, 'value': '11.25'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 4, 'value': '125.6'}
# {'datetime': '2025-04-21 19:20', 'sensor_id': 3, 'value': '5.5'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 12, 'value': '34.62'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 5, 'value': '10.97'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 8, 'value': '11.28'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 6, 'value': '19.16'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 2, 'value': '98.58'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 11, 'value': '96920.0'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 1, 'value': '11.25'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 10, 'value': '11.05'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 7, 'value': '11.25'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 4, 'value': '99.2'}
# {'datetime': '2025-04-21 19:15', 'sensor_id': 3, 'value': '4.1'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 12, 'value': '38.52'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 5, 'value': '10.92'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 8, 'value': '11.27'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 6, 'value': '19.3'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 2, 'value': '98.42'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 11, 'value': '96910.0'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 1, 'value': '11.24'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 10, 'value': '11.02'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 7, 'value': '11.24'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 4, 'value': '103.2'}
# {'datetime': '2025-04-21 19:10', 'sensor_id': 3, 'value': '3.2'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 12, 'value': '38.28'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 5, 'value': '10.96'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 8, 'value': '11.30'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 6, 'value': '19.23'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 2, 'value': '98.43'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 11, 'value': '96900.0'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 1, 'value': '11.27'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 10, 'value': '11.05'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 7, 'value': '11.27'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 4, 'value': '105.7'}
# {'datetime': '2025-04-21 19:05', 'sensor_id': 3, 'value': '4.6'}
# {'datetime': '2025-04-21 19:00', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 19:00', 'sensor_id': 12, 'value': '38.52'}
# {'datetime': '2025-04-21 19:00', 'sensor_id': 5, 'value': '11.02'}
# {'datetime': '2025-04-21 19:00', 'sensor_id': 8, 'value': '11.37'}
# {'datetime': '2025-04-21 19:00', 'sensor_id': 6, 'value': '19.11'}
# ...
# {'datetime': '2025-04-21 18:05', 'sensor_id': 5, 'value': '11.07'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 8, 'value': '11.40'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 6, 'value': '19.01'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 2, 'value': '98.48'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 1, 'value': '11.37'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 10, 'value': '11.16'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 7, 'value': '11.37'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 4, 'value': '144.5'}
# {'datetime': '2025-04-21 18:05', 'sensor_id': 3, 'value': '4.7'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 12, 'value': '37.79'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 5, 'value': '11.0'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 8, 'value': '11.34'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 6, 'value': '19.14'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 2, 'value': '98.45'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 1, 'value': '11.31'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 10, 'value': '11.09'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 7, 'value': '11.31'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 4, 'value': '131.8'}
# {'datetime': '2025-04-21 18:00', 'sensor_id': 3, 'value': '5.5'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 12, 'value': '39.26'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 5, 'value': '10.97'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 8, 'value': '11.32'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 6, 'value': '19.22'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 2, 'value': '98.39'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 1, 'value': '11.29'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 10, 'value': '11.07'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 7, 'value': '11.29'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 4, 'value': '141.5'}
# {'datetime': '2025-04-21 17:55', 'sensor_id': 3, 'value': '7.9'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 12, 'value': '40.72'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 5, 'value': '11.01'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 8, 'value': '11.37'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 6, 'value': '19.17'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 2, 'value': '98.33'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 1, 'value': '11.34'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 10, 'value': '11.11'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 7, 'value': '11.34'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 4, 'value': '141.3'}
# {'datetime': '2025-04-21 17:50', 'sensor_id': 3, 'value': '6.9'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 12, 'value': '39.01'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 5, 'value': '11.13'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 8, 'value': '11.48'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 6, 'value': '18.92'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 2, 'value': '98.4'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 11, 'value': '96860.0'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 1, 'value': '11.45'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 10, 'value': '11.23'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 7, 'value': '11.45'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 4, 'value': '152.9'}
# {'datetime': '2025-04-21 17:45', 'sensor_id': 3, 'value': '5.8'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 12, 'value': '39.50'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 5, 'value': '11.18'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 8, 'value': '11.53'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 6, 'value': '18.84'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 2, 'value': '98.38'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 1, 'value': '11.5'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 10, 'value': '11.28'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 7, 'value': '11.5'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 4, 'value': '129.7'}
# {'datetime': '2025-04-21 17:40', 'sensor_id': 3, 'value': '6.2'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 12, 'value': '39.50'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 5, 'value': '11.21'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 8, 'value': '11.56'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 6, 'value': '18.79'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 2, 'value': '98.38'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 1, 'value': '11.53'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 10, 'value': '11.31'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 7, 'value': '11.53'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 4, 'value': '136.0'}
# {'datetime': '2025-04-21 17:35', 'sensor_id': 3, 'value': '5.5'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 12, 'value': '39.74'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 5, 'value': '11.18'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 8, 'value': '11.54'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 6, 'value': '18.83'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 2, 'value': '98.37'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 1, 'value': '11.51'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 10, 'value': '11.29'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 7, 'value': '11.51'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 4, 'value': '128.2'}
# {'datetime': '2025-04-21 17:30', 'sensor_id': 3, 'value': '6.8'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 12, 'value': '41.94'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 5, 'value': '11.16'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 8, 'value': '11.53'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 6, 'value': '18.92'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 2, 'value': '98.28'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 11, 'value': '96840.0'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 1, 'value': '11.5'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 10, 'value': '11.27'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 7, 'value': '11.5'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 4, 'value': '141.7'}
# {'datetime': '2025-04-21 17:25', 'sensor_id': 3, 'value': '4.6'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 12, 'value': '36.82'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 5, 'value': '11.27'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 8, 'value': '11.59'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 6, 'value': '18.64'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 2, 'value': '98.49'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 1, 'value': '11.57'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 10, 'value': '11.36'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 7, 'value': '11.57'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 4, 'value': '127.8'}
# {'datetime': '2025-04-21 17:20', 'sensor_id': 3, 'value': '8.0'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 12, 'value': '36.09'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 5, 'value': '11.2'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 8, 'value': '11.52'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 6, 'value': '18.74'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 2, 'value': '98.52'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 1, 'value': '11.5'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 10, 'value': '11.29'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 7, 'value': '11.5'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 4, 'value': '127.4'}
# {'datetime': '2025-04-21 17:15', 'sensor_id': 3, 'value': '5.0'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 12, 'value': '40.23'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 5, 'value': '10.99'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 8, 'value': '11.35'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 6, 'value': '19.2'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 2, 'value': '98.35'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 1, 'value': '11.32'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 10, 'value': '11.09'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 7, 'value': '11.32'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 4, 'value': '137.5'}
# {'datetime': '2025-04-21 17:10', 'sensor_id': 3, 'value': '5.1'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 12, 'value': '40.23'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 5, 'value': '11.0'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 8, 'value': '11.36'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 6, 'value': '19.18'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 2, 'value': '98.35'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 11, 'value': '96860.0'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 1, 'value': '11.33'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 10, 'value': '11.10'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 7, 'value': '11.33'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 4, 'value': '143.2'}
# {'datetime': '2025-04-21 17:05', 'sensor_id': 3, 'value': '5.7'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 12, 'value': '39.26'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 5, 'value': '10.97'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 8, 'value': '11.32'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 6, 'value': '19.22'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 2, 'value': '98.39'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 1, 'value': '11.29'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 10, 'value': '11.07'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 7, 'value': '11.29'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 4, 'value': '138.5'}
# {'datetime': '2025-04-21 17:00', 'sensor_id': 3, 'value': '5.8'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 12, 'value': '40.23'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 5, 'value': '10.97'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 8, 'value': '11.33'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 6, 'value': '19.23'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 2, 'value': '98.35'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 11, 'value': '96850.0'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 1, 'value': '11.3'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 10, 'value': '11.07'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 7, 'value': '11.3'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 4, 'value': '141.5'}
# {'datetime': '2025-04-21 16:55', 'sensor_id': 3, 'value': '6.7'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 12, 'value': '40.23'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 5, 'value': '11.03'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 8, 'value': '11.39'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 6, 'value': '19.12'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 2, 'value': '98.35'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 11, 'value': '96840.0'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 1, 'value': '11.36'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 10, 'value': '11.13'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 7, 'value': '11.36'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 4, 'value': '149.3'}
# {'datetime': '2025-04-21 16:50', 'sensor_id': 3, 'value': '7.4'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 12, 'value': '43.16'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 5, 'value': '11.16'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 8, 'value': '11.54'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 6, 'value': '18.93'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 2, 'value': '98.23'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 11, 'value': '96830.0'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 1, 'value': '11.51'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 10, 'value': '11.27'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 7, 'value': '11.51'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 4, 'value': '142.7'}
# {'datetime': '2025-04-21 16:45', 'sensor_id': 3, 'value': '8.3'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 12, 'value': '35.36'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 5, 'value': '11.37'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 8, 'value': '11.68'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 6, 'value': '18.43'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 2, 'value': '98.55'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 11, 'value': '96820.0'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 1, 'value': '11.66'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 10, 'value': '11.46'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 7, 'value': '11.66'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 4, 'value': '146.8'}
# {'datetime': '2025-04-21 16:40', 'sensor_id': 3, 'value': '7.5'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 12, 'value': '35.60'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 5, 'value': '11.26'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 8, 'value': '11.57'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 6, 'value': '18.63'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 2, 'value': '98.54'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 11, 'value': '96830.0'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 1, 'value': '11.55'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 10, 'value': '11.34'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 7, 'value': '11.55'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 4, 'value': '141.3'}
# {'datetime': '2025-04-21 16:35', 'sensor_id': 3, 'value': '5.1'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 9, 'value': '0.10'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 12, 'value': '37.31'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 5, 'value': '11.24'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 8, 'value': '11.57'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 6, 'value': '18.69'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 2, 'value': '98.47'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 11, 'value': '96820.0'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 1, 'value': '11.55'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 10, 'value': '11.34'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 7, 'value': '11.55'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 4, 'value': '140.7'}
# {'datetime': '2025-04-21 16:30', 'sensor_id': 3, 'value': '6.3'}

# %%
baseUrl = 'http://127.0.0.1:8000'
sensor_reading_url = f"{baseUrl}/api/reading/"

readings = df_readings.to_dict('records')
for reading in readings:
    post_request(reading, sensor_reading_url)
# Out:
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
# 201
